# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import requests
import pandas as pd
from collections.abc import Sequence

# %%
executable_path = {'executable_path': 'C:\Windows\chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = "https://www.profootballhof.com/news/super-bowl-starting-qbs/"
browser.visit(url)
html = browser.html
soup = bs(html, 'html.parser')

# %%
url = "https://www.profootballhof.com/news/super-bowl-starting-qbs/"
response = requests.get(url)
soup = bs(response.text, 'html.parser')

# %%
main_content = soup.find('tbody')
print(main_content)
# Out:
# <tbody>
# <tr>
# <td class="header2" width="13%"><strong>Super Bowl</strong></td>
# <td align="center" class="header2" width="10%">
# <div align="center"><strong>Date</strong></div>
# </td>
# <td class="header2" width="36%"><strong>Starting Quarterback/Team</strong></td>
# <td class="header2" width="21%"><strong>College</strong></td>
# <td class="header2" width="15%"><strong>Date of Birth</strong></td>
# <td class="header2" width="5%"><strong class="header2">Age</strong></td>
# </tr>
# <tr>
# <td align="center" class="row1" rowspan="2" width="13%">I</td>
# <td align="center" class="row1" rowspan="2" width="10%">
# <div align="center">1/15/67</div>
# </td>
# <td class="row1" width="36%"><strong>BART STARR</strong>, Green Bay Packers</td>
# <td class="row1" width="21%">Alabama</td>
# <td class="row1" width="15%">1/9/34</td>
# <td class="row1" width="5%">33</td>
# </tr>
# <tr>
# <td class="row1" width="36%"><strong>LEN DAWSON</strong>, Kansas City Chiefs</td>
# ...

# %%
main_content = soup.find('tbody')
main_content
# Out:
# <tbody>
# <tr>
# <td class="header2" width="13%"><strong>Super Bowl</strong></td>
# <td align="center" class="header2" width="10%">
# <div align="center"><strong>Date</strong></div>
# </td>
# <td class="header2" width="36%"><strong>Starting Quarterback/Team</strong></td>
# <td class="header2" width="21%"><strong>College</strong></td>
# <td class="header2" width="15%"><strong>Date of Birth</strong></td>
# <td class="header2" width="5%"><strong class="header2">Age</strong></td>
# </tr>
# <tr>
# <td align="center" class="row1" rowspan="2" width="13%">I</td>
# <td align="center" class="row1" rowspan="2" width="10%">
# <div align="center">1/15/67</div>
# </td>
# <td class="row1" width="36%"><strong>BART STARR</strong>, Green Bay Packers</td>
# <td class="row1" width="21%">Alabama</td>
# <td class="row1" width="15%">1/9/34</td>
# <td class="row1" width="5%">33</td>
# </tr>
# <tr>
# <td class="row1" width="36%"><strong>LEN DAWSON</strong>, Kansas City Chiefs</td>
# ...

# %%
results = main_content('td', class_='row1')
results[5].text
# Out:
# '33'

# %%
browser.quit()

# %%
url = "https://www.profootballhof.com/news/super-bowl-starting-qbs/"
browser.visit(url)
html = browser.html
soup = bs(html, 'html.parser')

name = []
college = []
dob = []
age = []
players = []

main_content = soup.find('tbody')
content = main_content('td', class_='row1')

for player in content:
    players.append(player.text)
# print(players[2])

    name.append(players[2])
print(name)
#     for athlete in players:
        
# #         player_name = athlete[2]
# #         player_college = athlete[3]
# #         player_dob = athlete[4]
# #         player_age = athlete[5]
        
#         name.append(athlete[2])
# #         college.append({"College": player_college})
# #         dob.append({"Date of Birth": player_dob})
# #         age.append({"Age": player_age})
    
# print(name)  
# #     print(college)
# #     print(dob)
# #     print(age)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-314-82600972a276> in <module>
#      17 # print(players[2])
#      18
# ---> 19     name.append(players[2])
#      20 print(name)
#      21 #     for athlete in players:
#
# IndexError: list index out of range

# %%
nfl_df = pd.DataFrame(players)
new_df.transpose()
new_df
# Out:
#   0            1                              2        3       4   5    \
# 0   I  \n1/15/67\n  BART STARR, Green Bay Packers  Alabama  1/9/34  33
#
#                               6       7        8   9    ...  274     275  \
# 0  LEN DAWSON, Kansas City Chiefs  Purdue  6/20/35  31  ...  LII  2/4/18
#
#                                276       277     278 279  \
# 0  Tom Brady, New England Patriots  Michigan  8/3/77  40
#
#                                280      281      282 283
# 0  Nick Foles, Philadelphia Eagles  Arizona  1/20/89  29
#
# [1 rows x 284 columns]

# %%
url = "https://www.profootballhof.com/news/super-bowl-starting-qbs/"
browser.visit(url)
html = browser.html
soup = bs(html, 'html.parser')

main_content = soup.find('tbody')
content = main_content('td', class_='row1')

# %%
player_name = main_content('td', width='36%')
name_df = pd.DataFrame(player_name)
name_df.columns = ["Starting Quarterback/Team"]
name_df
# Out:
#                     Starting Quarterback/Team
# 0               [[Starting Quarterback/Team]]
# 1         [[BART STARR], , Green Bay Packers]
# 2        [[LEN DAWSON], , Kansas City Chiefs]
# 3         [[BART STARR], , Green Bay Packers]
# 4          [Daryle Lamonica, Oakland Raiders]
# ..                                        ...
# 76         [Jake Delhomme, Carolina Panthers]
# 77          [Tom Brady, New England Patriots]
# 78      [Donovan McNabb, Philadelphia Eagles]
# 79  [Ben Roethlisberger, Pittsburgh Steelers]
# 80        [Matt Hasselbeck, Seattle Seahawks]
#
# [81 rows x 1 columns]

# %%
player_college = main_content('td', width='21%')
college_df = pd.DataFrame(player_college)
college_df.columns
college_df

player_college
# Out:
# [<td class="header2" width="21%"><strong>College</strong></td>,
#  <td class="row1" width="21%">Alabama</td>,
#  <td class="row1" width="21%">Purdue</td>,
#  <td class="row2" width="21%">Alabama</td>,
#  <td class="row2" width="21%">Notre Dame</td>,
#  <td class="row1" width="21%">Alabama</td>,
#  <td class="row1" width="21%">Michigan State</td>,
#  <td class="row2" width="21%">Purdue</td>,
#  <td class="row2" width="21%">California</td>,
#  <td class="row1" width="21%">Louisville</td>,
#  <td class="row1" width="21%">California</td>,
#  <td class="row2" width="21%">Navy</td>,
#  <td class="row2" width="21%">Purdue</td>,
#  <td class="row1" width="21%">Purdue</td>,
#  <td class="row1" width="21%">UCLA</td>,
#  <td class="row2" width="21%">Purdue</td>,
#  <td class="row2" width="21%">Georgia</td>,
#  <td class="row1" width="21%">Louisiana Tech</td>,
#  <td class="row1" width="21%">Georgia</td>,
#  <td class="row2" width="21%">Louisiana Tech</td>,
# ...
